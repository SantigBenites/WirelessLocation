# %%
# ------------------------------------------------
import os, json, re, glob
from typing import Dict, Any, List, Tuple, Optional
import numpy as np
import torch
import pandas as pd

# Project imports
import sys
sys.path.append("/mnt/data")
from model_generation import GeneratedModel
from data_processing import get_dataset, combine_arrays, split_combined_data

# ---------- PyTorch 2.6 safe deserialization helpers ----------
try:
    from torch.serialization import add_safe_globals
    import torch.torch_version
    add_safe_globals([torch.torch_version.TorchVersion])
except Exception:
    pass

def safe_torch_load(path: str, map_location="cpu"):
    try:
        return torch.load(path, map_location=map_location)  # weights_only=True by default on 2.6
    except Exception as e1:
        print(f"⚠️ safe_torch_load: retrying with weights_only=False for {os.path.basename(path)} "
              f"(only do this if you trust the source). Error was: {e1}")
        return torch.load(path, map_location=map_location, weights_only=False)

# ---------- Defaults pulled from your search space ----------
DEFAULTS = {
    'num_conv_layers': 3,
    'filters_per_layer': 64,
    'kernel_size': 5,
    'stride': 1,
    'padding': 'same',
    'activation': 'relu',
    'batch_norm': True,
    'use_dropout': False,
    'dropout': 0.0,
    'pooling_type': 'none',
    'pool_size': 2,
    'residual_connections': False,
    'normalization': 'none',
    'initialization': 'default',
    'optimizer': 'adam',
    'learning_rate': 1e-3,
    'weight_decay': 0.0,
    'batch_size': 256,
}

REQUIRED_KEYS = [
    'num_conv_layers','filters_per_layer','kernel_size','stride','padding',
    'activation','batch_norm','use_dropout','dropout','pooling_type','pool_size',
    'residual_connections','normalization','initialization'
]

# %%
def find_model_dirs(root: str) -> List[str]:
    """A model dir contains model_package.pth OR (config.json AND weights.pth)."""
    out = []
    for path in glob.glob(os.path.join(root, "*")):
        if not os.path.isdir(path):
            continue
        if (os.path.isfile(os.path.join(path, "model_package.pth")) or
            (os.path.isfile(os.path.join(path, "config.json")) and os.path.isfile(os.path.join(path, "weights.pth")))):
            out.append(path)
    return sorted(out)

def load_arch_and_state_and_ckpt(model_dir: str):
    """
    Returns (arch_config, state_dict, ckpt_path or None).
    Prefers model_package.pth; falls back to config.json + weights.pth.
    """
    pkg = os.path.join(model_dir, "model_package.pth")
    if os.path.isfile(pkg):
        pkg_data = safe_torch_load(pkg, map_location="cpu")
        arch_config = pkg_data.get("arch_config", {}) or {}
        state_dict  = pkg_data["state_dict"]
        # try to locate a copied original ckpt for later repair
        ckpts = glob.glob(os.path.join(model_dir, "*.ckpt"))
        ckpt_path = ckpts[0] if ckpts else None
        return arch_config, state_dict, ckpt_path

    cfg_path = os.path.join(model_dir, "config.json")
    wts_path = os.path.join(model_dir, "weights.pth")
    if not (os.path.isfile(cfg_path) and os.path.isfile(wts_path)):
        raise FileNotFoundError(f"missing model files in {model_dir}")
    with open(cfg_path, "r", encoding="utf-8") as f:
        cfg = json.load(f)
    arch_config = cfg.get("arch_config", {}) or {}
    state_dict = safe_torch_load(wts_path, map_location="cpu")
    ckpts = glob.glob(os.path.join(model_dir, "*.ckpt"))
    ckpt_path = ckpts[0] if ckpts else None
    return arch_config, state_dict, ckpt_path

def infer_from_state(state: Dict[str, torch.Tensor]) -> Dict[str, Any]:
    """Infer a few fields from state_dict (best-effort)."""
    # Count conv blocks
    num_layers = None
    pat = re.compile(r"^(?:model\.)?conv_blocks\.(\d+)\.")
    max_idx = -1
    for k in state.keys():
        m = pat.match(k)
        if m:
            max_idx = max(max_idx, int(m.group(1)))
    if max_idx >= 0:
        num_layers = max_idx + 1

    # Find a conv weight to read out_channels and kernel_size
    filters = None
    kernel = None
    for k, v in state.items():
        if k.endswith("weight") and isinstance(v, torch.Tensor) and v.ndim == 3:
            # Conv1d: [out_channels, in_channels, kernel_size]
            oc, ic, ks = v.shape
            filters = oc
            kernel = ks
            break

    # Residual connections: presence of projections.* is a hint
    residual = any(re.match(r"^(?:model\.)?projections\.\d+\.", k) for k in state.keys())

    return {
        "num_conv_layers": num_layers,
        "filters_per_layer": filters,
        "kernel_size": kernel,
        "residual_connections": residual,
    }

def try_arch_from_ckpt(ckpt_path: Optional[str]) -> Dict[str, Any]:
    """Try to recover hyper parameters from original Lightning .ckpt."""
    if not ckpt_path or not os.path.isfile(ckpt_path):
        return {}
    try:
        ckpt = safe_torch_load(ckpt_path, map_location="cpu")
        hp = ckpt.get("hyper_parameters") or ckpt.get("hparams") or {}
        # common patterns: either a nested dict or flat keys
        if isinstance(hp, dict):
            if "architecture_config" in hp and isinstance(hp["architecture_config"], dict):
                return hp["architecture_config"]
            # else try to pick expected keys from flat hp
            extracted = {k: hp[k] for k in REQUIRED_KEYS if k in hp}
            # handle alt names
            if "use_dropout" not in extracted and "dropout" in hp:
                extracted["use_dropout"] = float(hp["dropout"]) > 0.0
            return extracted
    except Exception as e:
        print(f"⚠️ could not read hyper_parameters from {os.path.basename(ckpt_path)}: {e}")
    return {}

def coerce_types(cfg: Dict[str, Any]) -> Dict[str, Any]:
    """Coerce to proper types expected by GeneratedModel."""
    out = dict(cfg)
    ints = {"num_conv_layers","filters_per_layer","kernel_size","stride","pool_size"}
    floats = {"dropout","learning_rate","weight_decay"}
    bools = {"batch_norm","use_dropout","residual_connections"}
    lowers = {"padding","activation","pooling_type","normalization","initialization","optimizer"}
    for k in list(out.keys()):
        v = out[k]
        try:
            if k in ints and v is not None:
                out[k] = int(v)
            elif k in floats and v is not None:
                out[k] = float(v)
            elif k in bools and v is not None:
                if isinstance(v, str):
                    out[k] = v.strip().lower() in ("true","1","yes")
                else:
                    out[k] = bool(v)
            elif k in lowers and v is not None:
                out[k] = str(v).strip().lower()
        except Exception:
            pass
    return out

def repair_arch_config(arch: Dict[str, Any], state: Dict[str, torch.Tensor], ckpt_path: Optional[str]) -> Dict[str, Any]:
    """Fill missing keys using ckpt hyperparameters, then state_dict inference, then defaults."""
    repaired = dict(arch or {})
    # 1) ckpt hyperparameters
    ckpt_arch = try_arch_from_ckpt(ckpt_path)
    for k, v in ckpt_arch.items():
        repaired.setdefault(k, v)
    # 2) state_dict inference (only for some keys)
    inferred = infer_from_state(state)
    for k, v in inferred.items():
        if v is not None:
            repaired.setdefault(k, v)
    # 3) defaults
    for k, v in DEFAULTS.items():
        repaired.setdefault(k, v)
    # types
    repaired = coerce_types(repaired)
    # make sure dropout flag is consistent
    if "use_dropout" in repaired and "dropout" in repaired:
        repaired["use_dropout"] = float(repaired["dropout"]) > 0.0 if repaired["dropout"] is not None else False
    return repaired

def clean_state_dict_for_model(state: Dict[str, torch.Tensor]) -> Dict[str, torch.Tensor]:
    out = {}
    for k, v in state.items():
        kk = k.split("model.", 1)[1] if k.startswith("model.") else k
        out[kk] = v.detach().cpu()
    return out

@torch.inference_mode()
def evaluate(model: torch.nn.Module, X: np.ndarray, y: np.ndarray, device: torch.device, batch_size: int = BATCH_SIZE):
    X_t = torch.as_tensor(X, dtype=torch.float32, device=device)
    preds = []
    for i in range(0, X_t.size(0), batch_size):
        xb = X_t[i:i+batch_size]
        preds.append(model(xb).detach().cpu().numpy())
    y_pred = np.vstack(preds).astype(np.float32)
    y_true = y.astype(np.float32)
    diff = y_pred - y_true
    mse = float(np.mean(diff**2))
    rmse = float(np.sqrt(mse))
    mae = float(np.mean(np.abs(diff)))
    return {"mse": mse, "rmse": rmse, "mae": mae}

# ---------- Collections and subset plan ----------
ALL_COLLECTIONS = [
    "equilatero_grande_garage",
    "equilatero_grande_outdoor",
    "equilatero_medio_garage",
    "equilatero_medio_outdoor",
    "isosceles_grande_indoor",
    "isosceles_grande_outdoor",
    "isosceles_medio_outdoor",
    "obtusangulo_grande_outdoor",
    "obtusangulo_pequeno_outdoor",
    "reto_grande_garage",
    "reto_grande_indoor",
    "reto_grande_outdoor",
    "reto_medio_garage",
    "reto_medio_outdoor",
    "reto_n_quadrado_grande_indoor",
    "reto_n_quadrado_grande_outdoor",
    "reto_n_quadrado_pequeno_outdoor",
    "reto_pequeno_garage",
    "reto_pequeno_outdoor",
]

def group_by_location(collections: List[str], locations: List[str]) -> List[str]:
    return [name for name in collections if any(loc in name for loc in locations)]

SUBSET_PLAN = {
    "garage":  group_by_location(ALL_COLLECTIONS, ["garage"]),
    "outdoor": group_by_location(ALL_COLLECTIONS, ["outdoor"]),
    "indoor":  group_by_location(ALL_COLLECTIONS, ["indoor"]),
}

def load_subset_data_cached(db_name: str):
    """Load garage/outdoor/indoor once and cache."""
    cache = {}
    for subset, colls in SUBSET_PLAN.items():
        arrays = [get_dataset(name, db_name) for name in colls]
        combined = combine_arrays(arrays)
        X, y = split_combined_data(combined)
        cache[subset] = (X, y)
    return cache

# %%
# =====================================================================
# CONFIGURATION (edit these variables as needed)
# =====================================================================
MODELS_ROOT = "/home/admindi/sbenites/WirelessLocation/validation/model_per_dataset_validation/full_models"
DB_NAME = "wifi_fingerprinting_data"
OUT_CSV = "export_models_validation_long.csv"
OUT_PIVOT_CSV = "export_models_validation_pivot.csv"
METRICS = "rmse"   # choose from "rmse", "mse", "mae"
LIMIT = 0          # 0 = evaluate all models, >0 = limit number
BATCH_SIZE = 4096
# =====================================================================


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

model_dirs = find_model_dirs(MODELS_ROOT)
print(f"Found {len(model_dirs)} model folders in {MODELS_ROOT}")

# Load data once
subset_cache = load_subset_data_cached(DB_NAME)
input_size, output_size = subset_cache["garage"][0].shape[1], subset_cache["garage"][1].shape[1]
print(f"Input/Output dims: {input_size} -> {output_size}")

rows = []
for mdir in model_dirs:
    model_name = os.path.basename(mdir.rstrip(os.sep))
    try:
        arch_raw, state, ckpt_path = load_arch_and_state_and_ckpt(mdir)
        arch = repair_arch_config(arch_raw, state, ckpt_path)
        if any(k not in arch for k in REQUIRED_KEYS):
            missing = [k for k in REQUIRED_KEYS if k not in arch]
            print(f"[{model_name}] ⚠️ architecture still missing {missing}; using defaults may degrade fidelity.")
        model = GeneratedModel(input_size=input_size, output_size=output_size, architecture_config=arch)
        cleaned = clean_state_dict_for_model(state)
        missing, unexpected = model.load_state_dict(cleaned, strict=False)
        if missing:
            print(f"[{model_name}] missing keys: {missing[:6]}{'...' if len(missing)>6 else ''}")
        if unexpected:
            print(f"[{model_name}] unexpected keys: {unexpected[:6]}{'...' if len(unexpected)>6 else ''}")
        model.to(device).eval()
    except Exception as e:
        print(f"[{model_name}] ❌ load failed after repair: {e}")
        continue

    for subset in ("garage","outdoor","indoor"):
        try:
            X, Y = subset_cache[subset]
            m = evaluate(model, X, Y, device=device)
            rows.append({"model": model_name, "subset": subset, **m})
            print(f"[{model_name}] ✅ {subset}: RMSE={m['rmse']:.4f} (MSE={m['mse']:.4f}, MAE={m['mae']:.4f})")
        except Exception as e:
            print(f"[{model_name}] ⚠️ eval {subset} failed: {e}")

# Display tables (no CSVs)
df = pd.DataFrame(rows).sort_values(["model", "subset"])
display(df[["model", "subset", "rmse", "mse", "mae"]])

pivot = df.pivot_table(index="model", columns="subset", values=METRIC_TO_PIVOT, aggfunc="min").reset_index()
display(pivot)
# Out:
# Device: cuda
# Found 105 model folders in /home/admindi/sbenites/WirelessLocation/validation/model_per_dataset_validation/full_models
# Input/Output dims: 3 -> 2
# [all_data_run0_depth7_model5] ✅ garage: RMSE=0.2954 (MSE=0.0872, MAE=0.2540)
# [all_data_run0_depth7_model5] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [all_data_run0_depth7_model5] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3212)
# [all_data_run0_depth8_model5] ❌ load failed: 'num_conv_layers'
# [all_data_run1_depth5_model1] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [all_data_run1_depth5_model1] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [all_data_run1_depth5_model1] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3211)
# [all_data_run1_depth5_model7] ❌ load failed: 'num_conv_layers'
# [all_data_run2_depth3_model0] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [all_data_run2_depth3_model0] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [all_data_run2_depth3_model0] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3212)
# [all_data_run2_depth5_model8] ❌ load failed: 'num_conv_layers'
# [all_data_run3_depth1_model7] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [all_data_run3_depth1_model7] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [all_data_run3_depth1_model7] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3212)
# [all_data_run3_depth2_model5] ❌ load failed: 'num_conv_layers'
# [all_data_run4_depth2_model5] ✅ garage: RMSE=0.2954 (MSE=0.0872, MAE=0.2540)
# [all_data_run4_depth2_model5] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [all_data_run4_depth2_model5] ✅ indoor: RMSE=0.3898 (MSE=0.1519, MAE=0.3212)
# [all_data_run4_depth9_model9] ❌ load failed: 'num_conv_layers'
# [all_data_run5_depth5_model3] ❌ load failed: 'num_conv_layers'
# [all_data_run6_depth0_model2] ❌ load failed: 'num_conv_layers'
# [all_data_run7_depth2_model7] ❌ load failed: 'num_conv_layers'
# [all_data_run8_depth1_model8] ❌ load failed: 'num_conv_layers'
# [all_data_run9_depth8_model8] ❌ load failed: 'num_conv_layers'
# [garage_only_run0_depth6_model0] ✅ garage: RMSE=0.2947 (MSE=0.0869, MAE=0.2537)
# [garage_only_run0_depth6_model0] ✅ outdoor: RMSE=0.2986 (MSE=0.0891, MAE=0.2554)
# [garage_only_run0_depth6_model0] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3214)
# [garage_only_run0_depth9_model4] ❌ load failed: 'num_conv_layers'
# [garage_only_run1_depth2_model2] ✅ garage: RMSE=0.2950 (MSE=0.0870, MAE=0.2546)
# [garage_only_run1_depth2_model2] ✅ outdoor: RMSE=0.3010 (MSE=0.0906, MAE=0.2576)
# [garage_only_run1_depth2_model2] ✅ indoor: RMSE=0.3824 (MSE=0.1463, MAE=0.3154)
# [garage_only_run1_depth8_model0] ❌ load failed: 'num_conv_layers'
# [garage_only_run2_depth3_model5] ✅ garage: RMSE=0.2945 (MSE=0.0867, MAE=0.2541)
# [garage_only_run2_depth3_model5] ✅ outdoor: RMSE=0.3025 (MSE=0.0915, MAE=0.2584)
# [garage_only_run2_depth3_model5] ✅ indoor: RMSE=0.3827 (MSE=0.1465, MAE=0.3156)
# [garage_only_run2_depth8_model7] ❌ load failed: 'num_conv_layers'
# [garage_only_run3_depth0_model3] ❌ load failed: 'num_conv_layers'
# [garage_only_run3_depth7_model0] ✅ garage: RMSE=0.2942 (MSE=0.0865, MAE=0.2536)
# [garage_only_run3_depth7_model0] ✅ outdoor: RMSE=0.2999 (MSE=0.0899, MAE=0.2564)
# [garage_only_run3_depth7_model0] ✅ indoor: RMSE=0.3877 (MSE=0.1503, MAE=0.3199)
# [garage_only_run4_depth4_model1] ✅ garage: RMSE=0.2936 (MSE=0.0862, MAE=0.2532)
# [garage_only_run4_depth4_model1] ✅ outdoor: RMSE=0.3008 (MSE=0.0905, MAE=0.2570)
# [garage_only_run4_depth4_model1] ✅ indoor: RMSE=0.3932 (MSE=0.1546, MAE=0.3243)
# [garage_only_run4_depth7_model10] ❌ load failed: 'num_conv_layers'
# [garage_only_run5_depth0_model2] ❌ load failed: 'num_conv_layers'
# [garage_only_run6_depth9_model3] ❌ load failed: 'num_conv_layers'
# [garage_only_run7_depth4_model10] ❌ load failed: 'num_conv_layers'
# [garage_only_run8_depth8_model4] ❌ load failed: 'num_conv_layers'
# [garage_only_run9_depth5_model10] ❌ load failed: 'num_conv_layers'
# [indoor_only_run0_depth3_model1] ✅ garage: RMSE=0.3297 (MSE=0.1087, MAE=0.2760)
# [indoor_only_run0_depth3_model1] ✅ outdoor: RMSE=0.3445 (MSE=0.1187, MAE=0.2847)
# [indoor_only_run0_depth3_model1] ✅ indoor: RMSE=0.3474 (MSE=0.1207, MAE=0.2919)
# [indoor_only_run0_depth5_model9] ❌ load failed: 'num_conv_layers'
# [indoor_only_run1_depth3_model10] ❌ load failed: 'num_conv_layers'
# [indoor_only_run1_depth6_model4] ✅ garage: RMSE=0.3411 (MSE=0.1164, MAE=0.2828)
# [indoor_only_run1_depth6_model4] ✅ outdoor: RMSE=0.3382 (MSE=0.1144, MAE=0.2813)
# [indoor_only_run1_depth6_model4] ✅ indoor: RMSE=0.3647 (MSE=0.1330, MAE=0.3058)
# [indoor_only_run2_depth7_model1] ✅ garage: RMSE=0.3860 (MSE=0.1490, MAE=0.3171)
# [indoor_only_run2_depth7_model1] ✅ outdoor: RMSE=0.4024 (MSE=0.1619, MAE=0.3288)
# [indoor_only_run2_depth7_model1] ✅ indoor: RMSE=0.3510 (MSE=0.1232, MAE=0.2934)
# [indoor_only_run2_depth8_model5] ❌ load failed: 'num_conv_layers'
# [indoor_only_run3_depth1_model1] ✅ garage: RMSE=0.3388 (MSE=0.1148, MAE=0.2821)
# [indoor_only_run3_depth1_model1] ✅ outdoor: RMSE=0.3431 (MSE=0.1177, MAE=0.2845)
# [indoor_only_run3_depth1_model1] ✅ indoor: RMSE=0.3526 (MSE=0.1243, MAE=0.2983)
# [indoor_only_run3_depth6_model7] ❌ load failed: 'num_conv_layers'
# [indoor_only_run4_depth6_model6] ✅ garage: RMSE=0.3552 (MSE=0.1262, MAE=0.2930)
# [indoor_only_run4_depth6_model6] ✅ outdoor: RMSE=0.3494 (MSE=0.1221, MAE=0.2895)
# [indoor_only_run4_depth6_model6] ✅ indoor: RMSE=0.3712 (MSE=0.1378, MAE=0.3107)
# [indoor_only_run4_depth7_model11] ❌ load failed: 'num_conv_layers'
# [indoor_only_run5_depth5_model4] ❌ load failed: 'num_conv_layers'
# [indoor_only_run6_depth1_model4] ❌ load failed: 'num_conv_layers'
# [indoor_only_run7_depth5_model0] ❌ load failed: 'num_conv_layers'
# [indoor_only_run8_depth5_model0] ❌ load failed: 'num_conv_layers'
# [indoor_only_run9_depth0_model6] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run0_depth2_model7] ✅ garage: RMSE=0.2961 (MSE=0.0877, MAE=0.2538)
# [outdoor_and_garage_run0_depth2_model7] ✅ outdoor: RMSE=0.2968 (MSE=0.0881, MAE=0.2543)
# [outdoor_and_garage_run0_depth2_model7] ✅ indoor: RMSE=0.3991 (MSE=0.1593, MAE=0.3283)
# [outdoor_and_garage_run0_depth6_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run1_depth6_model11] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run1_depth7_model7] ✅ garage: RMSE=0.2982 (MSE=0.0889, MAE=0.2548)
# [outdoor_and_garage_run1_depth7_model7] ✅ outdoor: RMSE=0.2966 (MSE=0.0880, MAE=0.2542)
# [outdoor_and_garage_run1_depth7_model7] ✅ indoor: RMSE=0.3987 (MSE=0.1590, MAE=0.3271)
# [outdoor_and_garage_run2_depth3_model4] ✅ garage: RMSE=0.4919 (MSE=0.2420, MAE=0.4098)
# [outdoor_and_garage_run2_depth3_model4] ✅ outdoor: RMSE=0.5181 (MSE=0.2684, MAE=0.4346)
# [outdoor_and_garage_run2_depth3_model4] ✅ indoor: RMSE=0.4081 (MSE=0.1665, MAE=0.3331)
# [outdoor_and_garage_run2_depth4_model2] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run3_depth2_model0] ✅ garage: RMSE=0.2948 (MSE=0.0869, MAE=0.2541)
# [outdoor_and_garage_run3_depth2_model0] ✅ outdoor: RMSE=0.2979 (MSE=0.0887, MAE=0.2554)
# [outdoor_and_garage_run3_depth2_model0] ✅ indoor: RMSE=0.4021 (MSE=0.1617, MAE=0.3312)
# [outdoor_and_garage_run3_depth8_model0] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run4_depth6_model4] ✅ garage: RMSE=0.2956 (MSE=0.0874, MAE=0.2539)
# [outdoor_and_garage_run4_depth6_model4] ✅ outdoor: RMSE=0.2970 (MSE=0.0882, MAE=0.2546)
# [outdoor_and_garage_run4_depth6_model4] ✅ indoor: RMSE=0.4008 (MSE=0.1606, MAE=0.3299)
# [outdoor_and_garage_run4_depth8_model7] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run5_depth4_model0] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run6_depth8_model4] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run7_depth5_model5] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run8_depth2_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_and_garage_run9_depth1_model10] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run0_depth5_model1] ✅ garage: RMSE=0.2973 (MSE=0.0884, MAE=0.2548)
# [outdoor_and_indoor_run0_depth5_model1] ✅ outdoor: RMSE=0.2977 (MSE=0.0886, MAE=0.2552)
# [outdoor_and_indoor_run0_depth5_model1] ✅ indoor: RMSE=0.3904 (MSE=0.1524, MAE=0.3209)
# [outdoor_and_indoor_run0_depth6_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run1_depth2_model3] ✅ garage: RMSE=0.3301 (MSE=0.1089, MAE=0.2751)
# [outdoor_and_indoor_run1_depth2_model3] ✅ outdoor: RMSE=0.3208 (MSE=0.1029, MAE=0.2698)
# [outdoor_and_indoor_run1_depth2_model3] ✅ indoor: RMSE=0.4786 (MSE=0.2291, MAE=0.3912)
# [outdoor_and_indoor_run1_depth6_model4] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run2_depth0_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run2_depth3_model0] ✅ garage: RMSE=0.2966 (MSE=0.0880, MAE=0.2549)
# [outdoor_and_indoor_run2_depth3_model0] ✅ outdoor: RMSE=0.2985 (MSE=0.0891, MAE=0.2558)
# [outdoor_and_indoor_run2_depth3_model0] ✅ indoor: RMSE=0.3868 (MSE=0.1496, MAE=0.3183)
# [outdoor_and_indoor_run3_depth6_model0] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run3_depth6_model7] ✅ garage: RMSE=0.2967 (MSE=0.0880, MAE=0.2556)
# [outdoor_and_indoor_run3_depth6_model7] ✅ outdoor: RMSE=0.3007 (MSE=0.0904, MAE=0.2574)
# [outdoor_and_indoor_run3_depth6_model7] ✅ indoor: RMSE=0.3806 (MSE=0.1448, MAE=0.3136)
# [outdoor_and_indoor_run4_depth5_model5] ✅ garage: RMSE=0.2982 (MSE=0.0889, MAE=0.2553)
# [outdoor_and_indoor_run4_depth5_model5] ✅ outdoor: RMSE=0.2976 (MSE=0.0885, MAE=0.2553)
# [outdoor_and_indoor_run4_depth5_model5] ✅ indoor: RMSE=0.3913 (MSE=0.1531, MAE=0.3212)
# [outdoor_and_indoor_run4_depth9_model7] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run5_depth4_model5] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run6_depth3_model3] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run7_depth5_model11] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run8_depth7_model3] ❌ load failed: 'num_conv_layers'
# [outdoor_and_indoor_run9_depth4_model9] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run0_depth0_model11] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run0_depth0_model5] ✅ garage: RMSE=0.2954 (MSE=0.0872, MAE=0.2540)
# [outdoor_indoor_and_garage_run0_depth0_model5] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [outdoor_indoor_and_garage_run0_depth0_model5] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3211)
# [outdoor_indoor_and_garage_run1_depth3_model5] ✅ garage: RMSE=0.2954 (MSE=0.0872, MAE=0.2540)
# [outdoor_indoor_and_garage_run1_depth3_model5] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [outdoor_indoor_and_garage_run1_depth3_model5] ✅ indoor: RMSE=0.3898 (MSE=0.1519, MAE=0.3212)
# [outdoor_indoor_and_garage_run1_depth9_model0] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run2_depth0_model11] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run2_depth7_model4] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [outdoor_indoor_and_garage_run2_depth7_model4] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [outdoor_indoor_and_garage_run2_depth7_model4] ✅ indoor: RMSE=0.3898 (MSE=0.1519, MAE=0.3212)
# [outdoor_indoor_and_garage_run3_depth2_model10] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run3_depth7_model7] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [outdoor_indoor_and_garage_run3_depth7_model7] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [outdoor_indoor_and_garage_run3_depth7_model7] ✅ indoor: RMSE=0.3897 (MSE=0.1519, MAE=0.3212)
# [outdoor_indoor_and_garage_run4_depth1_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run4_depth6_model0] ✅ garage: RMSE=0.2954 (MSE=0.0873, MAE=0.2540)
# [outdoor_indoor_and_garage_run4_depth6_model0] ✅ outdoor: RMSE=0.2981 (MSE=0.0889, MAE=0.2552)
# [outdoor_indoor_and_garage_run4_depth6_model0] ✅ indoor: RMSE=0.3898 (MSE=0.1519, MAE=0.3212)
# [outdoor_indoor_and_garage_run5_depth1_model10] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run6_depth0_model6] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run7_depth9_model0] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run8_depth9_model5] ❌ load failed: 'num_conv_layers'
# [outdoor_indoor_and_garage_run9_depth3_model7] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run0_depth4_model11] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run0_depth6_model2] ✅ garage: RMSE=0.2986 (MSE=0.0891, MAE=0.2552)
# [outdoor_only_run0_depth6_model2] ✅ outdoor: RMSE=0.2964 (MSE=0.0879, MAE=0.2545)
# [outdoor_only_run0_depth6_model2] ✅ indoor: RMSE=0.4057 (MSE=0.1646, MAE=0.3325)
# [outdoor_only_run1_depth1_model4] ✅ garage: RMSE=0.2989 (MSE=0.0893, MAE=0.2552)
# [outdoor_only_run1_depth1_model4] ✅ outdoor: RMSE=0.2965 (MSE=0.0879, MAE=0.2543)
# [outdoor_only_run1_depth1_model4] ✅ indoor: RMSE=0.4019 (MSE=0.1615, MAE=0.3295)
# [outdoor_only_run1_depth9_model4] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run2_depth3_model9] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run2_depth6_model5] ✅ garage: RMSE=0.2985 (MSE=0.0891, MAE=0.2549)
# [outdoor_only_run2_depth6_model5] ✅ outdoor: RMSE=0.2964 (MSE=0.0878, MAE=0.2542)
# [outdoor_only_run2_depth6_model5] ✅ indoor: RMSE=0.4029 (MSE=0.1623, MAE=0.3304)
# [outdoor_only_run3_depth0_model0] ✅ garage: RMSE=0.2993 (MSE=0.0896, MAE=0.2557)
# [outdoor_only_run3_depth0_model0] ✅ outdoor: RMSE=0.2964 (MSE=0.0879, MAE=0.2545)
# [outdoor_only_run3_depth0_model0] ✅ indoor: RMSE=0.4058 (MSE=0.1647, MAE=0.3327)
# [outdoor_only_run3_depth1_model4] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run4_depth2_model1] ✅ garage: RMSE=0.2990 (MSE=0.0894, MAE=0.2553)
# [outdoor_only_run4_depth2_model1] ✅ outdoor: RMSE=0.2965 (MSE=0.0879, MAE=0.2543)
# [outdoor_only_run4_depth2_model1] ✅ indoor: RMSE=0.4008 (MSE=0.1607, MAE=0.3286)
# [outdoor_only_run4_depth8_model2] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run5_depth6_model8] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run6_depth6_model6] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run7_depth4_model1] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run8_depth9_model2] ❌ load failed: 'num_conv_layers'
# [outdoor_only_run9_depth5_model3] ❌ load failed: 'num_conv_layers'
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 53
#      51 # Display tables (no CSVs)
#      52 df = pd.DataFrame(rows).sort_values(["model", "subset"])
# ---> 53 display(df[["model", "subset", *METRICS_TO_SHOW]])
#
# NameError: name 'METRICS_TO_SHOW' is not defined

# %%
import pandas as pd
table_path = "/home/sbenites/Documents/WirelessLocation/validation/wandb_graphs/MLP/runs_table.csv"

# MSE GRAPHS
table_pd = pd.read_csv(table_path)

run_name_to_name = {
    "1triangle_all_spaces_meters" : "1 triangle in all spaces", 
    "1triangle_2space_garage_outdoor" : "1 triangle in outdoor and garage", 
    "1triangle_1space_garage_small" : "smallest triangle in garage", 
    "1triangle_1space_outdoor_small" : "smallest triangle in outdoor", 
    "all_triangles_all_spaces" : "all triangles in all spaces", 
    "all_triangles_1space_outdoor" : "all traingles in outdoor", 
    "1triangle_all_spaces" : "1 triangles in all spaces", 
    "1triangle_1space_garage" : "1 triangles in garage", 
    "1triangle_1space_outdoor" : "1 triangles in outdoor", 
    "1triangle_1space_indoor" : "1 triangles in indoor"
    }


table_pd["run_name"] =  table_pd["run_name"].map(run_name_to_name) 
styled = table_pd.style.background_gradient(cmap="RdYlGn_r")  # _r reverses so green=low, red=high
styled
# Out:
# <style type="text/css">
# #T_20f96_row0_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_20f96_row0_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_20f96_row0_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_20f96_row0_col4, #T_20f96_row6_col4 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_20f96_row1_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_20f96_row1_col2, #T_20f96_row1_col3 {
#   background-color: #fff5ae;
#   color: #000000;
# }
# #T_20f96_row1_col4 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_20f96_row2_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_20f96_row2_col2 {
#   background-color: #dcf08f;
#   color: #000000;
# }
# #T_20f96_row2_col3 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_20f96_row2_col4 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_20f96_row3_col1 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_20f96_row3_col2 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_20f96_row3_col3 {
#   background-color: #e2f397;
#   color: #000000;
# }
# #T_20f96_row3_col4, #T_20f96_row8_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_20f96_row4_col1, #T_20f96_row4_col2, #T_20f96_row4_col3, #T_20f96_row4_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_20f96_row5_col1 {
#   background-color: #ec5c3b;
#   color: #f1f1f1;
# }
# #T_20f96_row5_col2 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_20f96_row5_col3 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_20f96_row5_col4 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_20f96_row6_col1 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_20f96_row6_col2 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_20f96_row6_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_20f96_row7_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_20f96_row7_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_20f96_row7_col3 {
#   background-color: #7fc866;
#   color: #000000;
# }
# #T_20f96_row7_col4 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_20f96_row8_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_20f96_row8_col2 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_20f96_row8_col3 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_20f96_row9_col1, #T_20f96_row9_col2, #T_20f96_row9_col3, #T_20f96_row9_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_20f96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20f96_level0_col0" class="col_heading level0 col0" >run_name</th>
#       <th id="T_20f96_level0_col1" class="col_heading level0 col1" >rmse_m</th>
#       <th id="T_20f96_level0_col2" class="col_heading level0 col2" >euclidean_error_m</th>
#       <th id="T_20f96_level0_col3" class="col_heading level0 col3" >mae_m</th>
#       <th id="T_20f96_level0_col4" class="col_heading level0 col4" >num_samples</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20f96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20f96_row0_col0" class="data row0 col0" >1 triangle in all spaces</td>
#       <td id="T_20f96_row0_col1" class="data row0 col1" >4.617473</td>
#       <td id="T_20f96_row0_col2" class="data row0 col2" >4.878425</td>
#       <td id="T_20f96_row0_col3" class="data row0 col3" >3.111416</td>
#       <td id="T_20f96_row0_col4" class="data row0 col4" >5532</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20f96_row1_col0" class="data row1 col0" >1 triangle in outdoor and garage</td>
#       <td id="T_20f96_row1_col1" class="data row1 col1" >6.320378</td>
#       <td id="T_20f96_row1_col2" class="data row1 col2" >6.998579</td>
#       <td id="T_20f96_row1_col3" class="data row1 col3" >4.493927</td>
#       <td id="T_20f96_row1_col4" class="data row1 col4" >4546</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20f96_row2_col0" class="data row2 col0" >smallest triangle in garage</td>
#       <td id="T_20f96_row2_col1" class="data row2 col1" >5.453987</td>
#       <td id="T_20f96_row2_col2" class="data row2 col2" >5.870619</td>
#       <td id="T_20f96_row2_col3" class="data row2 col3" >3.717448</td>
#       <td id="T_20f96_row2_col4" class="data row2 col4" >2501</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20f96_row3_col0" class="data row3 col0" >smallest triangle in outdoor</td>
#       <td id="T_20f96_row3_col1" class="data row3 col1" >5.803291</td>
#       <td id="T_20f96_row3_col2" class="data row3 col2" >6.027876</td>
#       <td id="T_20f96_row3_col3" class="data row3 col3" >3.865864</td>
#       <td id="T_20f96_row3_col4" class="data row3 col4" >2045</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20f96_row4_col0" class="data row4 col0" >all triangles in all spaces</td>
#       <td id="T_20f96_row4_col1" class="data row4 col1" >8.961236</td>
#       <td id="T_20f96_row4_col2" class="data row4 col2" >11.240767</td>
#       <td id="T_20f96_row4_col3" class="data row4 col3" >7.229940</td>
#       <td id="T_20f96_row4_col4" class="data row4 col4" >36994</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20f96_row5_col0" class="data row5 col0" >all traingles in outdoor</td>
#       <td id="T_20f96_row5_col1" class="data row5 col1" >7.778711</td>
#       <td id="T_20f96_row5_col2" class="data row5 col2" >9.743321</td>
#       <td id="T_20f96_row5_col3" class="data row5 col3" >6.303551</td>
#       <td id="T_20f96_row5_col4" class="data row5 col4" >22661</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20f96_row6_col0" class="data row6 col0" >1 triangles in all spaces</td>
#       <td id="T_20f96_row6_col1" class="data row6 col1" >6.575804</td>
#       <td id="T_20f96_row6_col2" class="data row6 col2" >7.664161</td>
#       <td id="T_20f96_row6_col3" class="data row6 col3" >4.873839</td>
#       <td id="T_20f96_row6_col4" class="data row6 col4" >5532</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20f96_row7_col0" class="data row7 col0" >1 triangles in garage</td>
#       <td id="T_20f96_row7_col1" class="data row7 col1" >4.217075</td>
#       <td id="T_20f96_row7_col2" class="data row7 col2" >4.361629</td>
#       <td id="T_20f96_row7_col3" class="data row7 col3" >2.790127</td>
#       <td id="T_20f96_row7_col4" class="data row7 col4" >2316</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20f96_row8_col0" class="data row8 col0" >1 triangles in outdoor</td>
#       <td id="T_20f96_row8_col1" class="data row8 col1" >4.672266</td>
#       <td id="T_20f96_row8_col2" class="data row8 col2" >5.090341</td>
#       <td id="T_20f96_row8_col3" class="data row8 col3" >3.244082</td>
#       <td id="T_20f96_row8_col4" class="data row8 col4" >1991</td>
#     </tr>
#     <tr>
#       <th id="T_20f96_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20f96_row9_col0" class="data row9 col0" >1 triangles in indoor</td>
#       <td id="T_20f96_row9_col1" class="data row9 col1" >2.161000</td>
#       <td id="T_20f96_row9_col2" class="data row9 col2" >2.151172</td>
#       <td id="T_20f96_row9_col3" class="data row9 col3" >1.385323</td>
#       <td id="T_20f96_row9_col4" class="data row9 col4" >1225</td>
#     </tr>
#   </tbody>
# </table>
